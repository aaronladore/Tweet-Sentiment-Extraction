# %% [markdown]
# # Importation de Libreries

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
from wordcloud import WordCloud, STOPWORDS
import tensorflow as tf
import missingno as msno
from collections import defaultdict
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import json
import torch

# %matplotlib inline

# %% [markdown]
# # Chargement des données

# %%
train = pd.read_csv("C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Input/train.csv")

test = pd.read_csv("C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Input/test.csv")

sample_submission = pd.read_csv("C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Input/sample_submission.csv")

# %%
train.shape, test.shape
# Out:
# ((27481, 4), (3534, 3))

# %% [markdown]
# # Trouver les valeurs manquantent

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,6))
plt.tight_layout(pad = 10)
msno.bar(train, ax = axes[0])
msno.bar(test, ax = axes[1])

# %% [markdown]
# ##### Il manque une valeur dans la colonne text et selected_text dans les données relatives aux trains

# %%
print(train[train["text"].isnull() == True])
# # Nous pouvons laisser tomber cette rangée
train.dropna(inplace = True)
# Out:
# textID text selected_text sentiment
# 314  fdb77c3752  NaN           NaN   neutral

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,6))
plt.tight_layout(pad = 10)
msno.bar(train, ax = axes[0])
msno.bar(test, ax = axes[1])

# %% [markdown]
# ##### Pas de valeur nulle dans le train et les données d'essai

# %% [markdown]
# # Répartition de la classe manquante

# %%
# Répartition de la classe de sentiment
fig, axes = plt.subplots(1, 2, figsize=(15,8))
fig.suptitle("Comparaison les données neutres négatives et positives dans les trains et les tests", fontsize = 25)
plt.tight_layout(pad = 3.5)
sns.countplot(x = "sentiment", data = train, ax = axes[0])
sns.countplot(x = "sentiment", data = test, ax = axes[1])
axes[0].set_xlabel("Sentiment", fontsize = 20)
axes[0].set_ylabel("Count", fontsize = 20)
axes[1].set_xlabel("Sentiment", fontsize = 20)
axes[1].set_ylabel("Count", fontsize = 20)
sns.despine()

# %% [markdown]
# ## Pourcentage de mots neutres, négatifs, positifs dans le train et données de test

# %%
def pert_count(data, category):
    return (len(data[data["sentiment"] == category])/len(data)) * 100

print(f"Pourcentage de mots neutres dans le train --> {pert_count(train, 'neutral')}%")
print(f"Pourcentage de mots negatifs dans le train --> {pert_count(train, 'negative')}%")
print(f"Pourcentage de mots positifs dans le train --> {pert_count(train, 'positive')}%")
print(f"Pourcentage de mots neutres dans le test --> {pert_count(test, 'neutral')}%")
print(f"Pourcentage de mots negatifs dans le test --> {pert_count(test, 'negative')}%")
print(f"Pourcentage de mots positifs dans le test --> {pert_count(test, 'positive')}%")
# Out:
# Pourcentage de mots neutres dans le train --> 40.45487627365357%
# Pourcentage de mots negatifs dans le train --> 28.315138282387192%
# Pourcentage de mots positifs dans le train --> 31.22998544395924%
# Pourcentage de mots neutres dans le test --> 40.46406338426712%
# Pourcentage de mots negatifs dans le test --> 28.324844368986984%
# Pourcentage de mots positifs dans le test --> 31.2110922467459%

# %% [markdown]
# #### L'analyse ci-dessus montre que le pourcentage de mots neutres, positifs et négatifs est assez similaire. Cela peut être dû au fait que les données relatives aux trains et aux tests proviennent du même échantillon

# %% [markdown]
# # Longueur des mots pour dans chaque catégorie

# %%
def len_sent(data):
    return len(data.split())

train["num_words_text"] = train["text"].apply(lambda x : len_sent(x))
test["num_words_text"] = test["text"].apply(lambda x : len_sent(x))
train["num_words_selected_text"] = train["selected_text"].apply(lambda x : len_sent(x))

# %%
fig, axes = plt.subplots(3, 1, sharey = True, figsize = (15, 20))
fig.suptitle("Comparer des trains et des tests en fonction de la longueur des sentiments", fontsize = 25)
sns.kdeplot(train[train["sentiment"] == "neutral"]["num_words_text"].values, ax  = axes[0], shade = True, color = "blue", label = "train")
sns.kdeplot(test[test["sentiment"] == "neutral"]["num_words_text"].values, ax  = axes[0], shade = True, color = "red", label = "test")
sns.kdeplot(train[train["sentiment"] == "negative"]["num_words_text"].values, ax  = axes[1], shade = True, color = "blue", label = "train")
sns.kdeplot(test[test["sentiment"] == "negative"]["num_words_text"].values, ax  = axes[1], shade = True, color = "red", label = "test")
sns.kdeplot(train[train["sentiment"] == "positive"]["num_words_text"].values, ax  = axes[2], shade = True, color = "blue", label = "train")
sns.kdeplot(test[test["sentiment"] == "positive"]["num_words_text"].values, ax  = axes[2], shade = True, color = "red", label = "test")
axes[0].set_xlabel("Longueur de sentiment neutre", fontsize = 20)
axes[0].set_ylabel("Distribution", fontsize = 20)
axes[1].set_xlabel("Longueur de sentiment negatif", fontsize = 20)
axes[1].set_ylabel("Distribution", fontsize = 20)
axes[2].set_xlabel("Longueur de sentiment positif", fontsize = 20)
axes[2].set_ylabel("Distribution", fontsize = 20)
plt.legend()

# %% [markdown]
# #### Nous pouvons voir sur les graphiques de distribution ci-dessus que la distribution de la longueur des mots est assez similaire dans les trains et les données de test pour chaque catégorie de sentiments

# %% [markdown]
# # Comparaison du test et de la colonne de texte sélectionnée

# %%
fig, axes = plt.subplots(3, 1, sharey = True, figsize = (15, 20))
fig.suptitle("", fontsize = 25)
sns.kdeplot(train[train["sentiment"] == "neutral"]["num_words_text"].values, ax  = axes[0], shade = True, color = "blue", label = "text")
sns.kdeplot(train[train["sentiment"] == "neutral"]["num_words_selected_text"].values, ax  = axes[0], shade = True, color = "red", label = "selected_text")
sns.kdeplot(train[train["sentiment"] == "negative"]["num_words_text"].values, ax  = axes[1], shade = True, color = "blue", label = "text")
sns.kdeplot(train[train["sentiment"] == "negative"]["num_words_selected_text"].values, ax  = axes[1], shade = True, color = "red", label = "selected_text")
sns.kdeplot(train[train["sentiment"] == "positive"]["num_words_text"].values, ax  = axes[2], shade = True, color = "blue", label = "text")
sns.kdeplot(train[train["sentiment"] == "positive"]["num_words_selected_text"].values, ax  = axes[2], shade = True, color = "red", label = "selected_text")
axes[0].set_xlabel("Longueur de sentiment neutre", fontsize = 20)
axes[0].set_ylabel("Distribution", fontsize = 20)
axes[1].set_xlabel("Longueur de sentiment negatif", fontsize = 20)
axes[1].set_ylabel("Distribution", fontsize = 20)
axes[2].set_xlabel("Longueur de sentiment positif", fontsize = 20)
axes[2].set_ylabel("Distribution", fontsize = 20)
plt.legend()

# %% [markdown]
# #### Nous pouvons voir sur les graphiques ci-dessus que pour les phrases neutres, la distribution de la longueur est approximativement la même dans la colonne text et selected_text. Pour les sentiments négatifs et positifs, la longueur de la colonne selected_text est plus courte que celle de la colonne de texte

# %% [markdown]
# # statistiques sur les textes
#
# ### Le pourcentage de phrases de la colonne de texte est égal à la colonne selected_text pour un sentiment neutre

# %%
train["text"] = train["text"].apply(lambda x : x.strip())
train["selected_text"] = train["selected_text"].apply(lambda x : x.strip())


train["is_equal"] = (train["text"] == train["selected_text"])
df_neutral = train[train["sentiment"] == "neutral"]
percentage = (len(df_neutral[df_neutral["is_equal"] == True])/len(df_neutral)) * 100
print(f"Le pourcentage de phrases de la colonne de texte est égal à la colonne selected_text pour un sentiment neutre --> {percentage}")
# Out:
# Le pourcentage de phrases de la colonne de texte est égal à la colonne selected_text pour un sentiment neutre --> 89.9883061977152

# %% [markdown]
# #### Comme la plupart des données du train ["text"] sont les mêmes que celles du train ["selected_text"] pour un sentiment neutre. Je vais donc simplement copier-coller le test ["text"] pour la prédiction du sentiment neutre

# %% [markdown]
# # Compte de la ponctuation

# %%
def punc_count(data):
    return len([w for w in data if w in string.punctuation])

train["text_punc_count"] = train["text"].apply(lambda x : punc_count(x))
train["selected_text_punc_count"] = train["selected_text"].apply(lambda x : punc_count(x))

# %%
plt.figure(figsize = (15, 8))
sns.kdeplot(train["text_punc_count"].values, shade = True, color = "blue", label = "Text punc count")
sns.kdeplot(train["selected_text_punc_count"].values, shade = True, color = "yellow", label = "Selected text punc count")
plt.title("Nombre de ponctuations", fontsize = 30)
plt.xlabel("Nombre de ponctuations", fontsize = 20)
plt.ylabel("Distribution", fontsize = 20)
sns.despine()
plt.legend(loc = "lower right")

# %% [markdown]
# # Nuage de mots

# %%
# Mots les plus répétés dans la colonne de texte et selected_text
stopwords = set(STOPWORDS)
def word_cloud(data, title):
    wordcloud = WordCloud(
    background_color = "black",
    max_font_size = 40,
    max_words = 200,
    stopwords = stopwords,
    scale = 3).generate(str(data))
    fig = plt.figure(figsize = (15, 15))
    plt.axis("off")
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.25)

    plt.imshow(wordcloud)
    plt.show()

# %%
word_cloud(train["text"], "Les Mots les plus répétés dans le train ['text'] ")

# %%
word_cloud(train[train["sentiment"] == "neutral"]["text"], "La plupart des mots répétés dans les phrases neutre dans le train['text']")

# %%
word_cloud(train[train["sentiment"] == "negative"]["text"], "La plupart des mots répétés dans les phrases negatives dans train['text']")

# %%
word_cloud(train[train["sentiment"] == "positive"]["text"], "La plupart des mots répétés dans les phrases positives dans train['text']")

# %% [markdown]
# # N-Grammes pour les phrases négatives neutres et positives

# %%
def n_grams(ngram, data):
    freq_dict = defaultdict(int)
    for text in data:
        tokens = [w for w in text.lower().split() if w != " " if w not in stopwords]
        ngrams = zip(*[tokens[i:] for i in range(ngram)])
        list_grams = [" ".join(ngram) for ngram in ngrams]
        for word in list_grams:
            freq_dict[word] += 1
    fd_sorted =  pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-1])   
    fd_sorted.columns = ["word", "wordcount"]
    return fd_sorted
                    
fd_sorted_neutral1 = n_grams(1, train[train["sentiment"] == "neutral"]["text"])    
fd_sorted_negative1 = n_grams(1, train[train["sentiment"] == "negative"]["text"])    
fd_sorted_positive1 = n_grams(1, train[train["sentiment"] == "positive"]["text"]) 

fd_sorted_neutral2 = n_grams(2, train[train["sentiment"] == "neutral"]["text"])    
fd_sorted_negative2 = n_grams(2, train[train["sentiment"] == "negative"]["text"])    
fd_sorted_positive2 = n_grams(2, train[train["sentiment"] == "positive"]["text"]) 

fd_sorted_neutral3 = n_grams(3, train[train["sentiment"] == "neutral"]["text"])    
fd_sorted_negative3 = n_grams(3, train[train["sentiment"] == "negative"]["text"])    
fd_sorted_positive3 = n_grams(3, train[train["sentiment"] == "positive"]["text"])

# %%
fig, axes = plt.subplots(3, 1, figsize = (10, 18))
plt.tight_layout(pad = 7.5)
plt.suptitle("unigrammes", fontsize = 25)
sns.despine()
l = ["neutral", "negative", "positive"]
for i in range(3):
    sns.barplot(x = "wordcount", y = "word", data = globals()["fd_sorted_" + str(l[i]) + str(1)].iloc[:20, :], ax = axes[i])
    axes[i].set_title(f"Mots les plus répétés dans des phrases  {l[i]}", fontsize = 20)
    axes[i].set_xlabel("Nb_Mots", fontsize = 15)    
    axes[i].set_ylabel("Mots", fontsize = 15)

# %%
fig, axes = plt.subplots(3, 1, figsize = (10, 18))
plt.tight_layout(pad = 7.5)
plt.suptitle("Bigrammes", fontsize = 25)
sns.despine()
l = ["neutral", "negative", "positive"]
for i in range(3):
    sns.barplot(x = "wordcount", y = "word", data = globals()["fd_sorted_" + str(l[i]) + str(2)].iloc[:20, :], ax = axes[i])
    axes[i].set_title(f"Mots les plus répétés dans des phrases  {l[i]} ", fontsize = 20)
    axes[i].set_xlabel("Nb_Mots", fontsize = 15)    
    axes[i].set_ylabel("Mots", fontsize = 15)

# %%
fig, axes = plt.subplots(3, 1, figsize = (10, 18))
plt.tight_layout(pad = 7.5)
plt.suptitle("Trigrammes", fontsize = 25)
sns.despine()
l = ["neutral", "negative", "positive"]
for i in range(3):
    sns.barplot(x = "wordcount", y = "word", data = globals()["fd_sorted_" + str(l[i]) + str(3)].iloc[:20, :], ax = axes[i])
    axes[i].set_title(f"Mots les plus répétés dans des phrases  {l[i]} ", fontsize = 20)
    axes[i].set_xlabel("Nb_Mots", fontsize = 15)    
    axes[i].set_ylabel("Mots", fontsize = 15)

# %% [markdown]
# # Modèle DistilBERT + SQuAD

# %% [markdown]
# ## Chargement de la données

# %%
train_array = np.array(train.iloc[:, :4])
test_array = np.array(test.iloc[:, :3])
use_cuda = True

# %% [markdown]
#  ## Préparation de la data

# %%
# Début de l'index de selected_text trouvé dans le texte

def start_index(text, selected_text):
    start_index = text.lower().find(selected_text.lower())
    l.append(start_index)
    
l = []
for i in range(len(train_array)):
    start_index(train_array[i, 1], train_array[i, 2])

# %%
# Nous prenons 
# question -> sentiment 
# context -> text
# answer -> selected_text

def quesa_format_train(train):
    out = []
    for i, row in enumerate(train):
        qas = []
        con = []
        ans = []
        question = row[-1]
        answer = row[2]
        context = row[1]
        qid = row[0]
        answer_start = l[i]
        ans.append({"answer_start": answer_start, "text": answer.lower()})
        qas.append({"question": question, "id": qid, "is_impossible": False, "answers": ans})
        out.append({"context": context.lower(), "qas": qas})

    return out
        
    
train_json_format = quesa_format_train(train_array)
with open('C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Ouput/train.json', 'w') as outfile:
    json.dump(train_json_format, outfile)

# %% [markdown]
# ##### De même pour les données text

# %%
# De même pour les données textuelles

def quesa_format_test(train):
    out = []
    for i, row in enumerate(train):
        qas = []
        con = []
        ans = []
        question = row[-1]
#         answer = row[2]
        context = row[1]
        qid = row[0]
        answer_start = l[i]
        ans.append({"answer_start": 1000000, "text": "__None__"})
        qas.append({"question": question, "id": qid, "is_impossible": False, "answers": ans})
        out.append({"context": context.lower(), "qas": qas})
    return out
        
    
test_json_format = quesa_format_test(test_array)

with open('C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Ouput/test.json', 'w') as outfile:
    json.dump(test_json_format, outfile)

# %% [markdown]
# ### Installation simple-transformater, un outil pour former et tester facilement le modèle des transformateurs
#
# https://github.com/ThilinaRajapakse/simpletransformers

# %% [markdown]
# #### !pip install 'C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Input/simple-transformers-pypi/seqeval-0.0.12-py3-none-any.whl' -q
#
# #### !pip install 'C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Input/simple-transformers-pypi/simpletransformers-0.22.1-py3-none-any.whl' -q

# %% [markdown]
# ## Modèle de train
#
# #### Entraînez le modèle de distillbert-base-uncased-distilled-squad

# %%
from simpletransformers.question_answering import QuestionAnsweringModel

model_path = 'C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Input/transformers-pretrained-distilbert/distilbert-base-uncased-distilled-squad/'

# Créer le modèle de question-réponse
model = QuestionAnsweringModel('distilbert', 
                               model_path, 
                               args={'reprocess_input_data': True,
                                     'overwrite_output_dir': True,
                                     'learning_rate': 5e-5,
                                     'num_train_epochs': 2,
                                     'max_seq_length': 220,
                                     'doc_stride': 64,
                                     'fp16': False,
                                    },
                              use_cuda=use_cuda)

model.train_model('C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Ouput/train.json')
# Out:
# 100%|██████████| 27480/27480 [00:28<00:00, 972.81it/s]
# Epoch:   0%|          | 0/2 [00:00<?, ?it/s]
# Running loss: 5.435658
# Running loss: 5.398391
# Running loss: 5.616568
# Running loss: 5.594458
# Running loss: 5.482367
# Running loss: 5.422046
# Running loss: 5.585928
# Running loss: 5.590217
# Running loss: 5.450796
# Running loss: 5.478086
# Running loss: 5.474395
# Running loss: 5.433888
# Running loss: 5.500152
# Running loss: 5.340748
# Running loss: 5.421765
# Running loss: 5.320637
# Running loss: 5.370572
# Running loss: 5.379397
# Running loss: 5.457588
# Running loss: 5.373054
# Running loss: 5.290310
# Running loss: 5.197032
# Running loss: 5.242089
# Running loss: 5.092806
# Running loss: 5.132213
# Running loss: 5.156178
# Running loss: 5.170197
# Running loss: 4.965319
# Running loss: 5.067748
# Running loss: 4.862179
# Running loss: 4.896480
# Running loss: 5.001253
# Running loss: 4.893441
# Running loss: 4.870538
# Running loss: 4.706621
# Running loss: 4.617321
# Running loss: 4.644447
# Running loss: 4.757533
# Running loss: 4.531764
# Running loss: 4.468399
# Running loss: 4.496241
# Running loss: 4.443605
# Running loss: 4.374290
# Running loss: 4.266726
# Running loss: 4.300825
# Running loss: 4.287565
# Running loss: 4.144546
# Running loss: 4.001514
# Running loss: 3.894418
# Running loss: 3.927465
# Running loss: 3.762848
# Running loss: 3.814500
# Running loss: 3.755722
# Running loss: 3.643765
# Running loss: 3.620843
# Running loss: 3.447949
# Running loss: 3.595735
# Running loss: 3.428610
# Running loss: 3.357610
# Running loss: 3.297405
# Running loss: 3.362639
# Running loss: 3.253534
# Running loss: 3.293153
# Running loss: 2.892049
# Running loss: 2.983840
# Running loss: 3.103516
# Running loss: 2.928103
# Running loss: 3.072089
# Running loss: 2.788982
# Running loss: 2.593190
# Running loss: 2.737121
# Running loss: 2.749091
# Running loss: 2.629322
# Running loss: 2.420235
# Running loss: 2.547324
# Running loss: 2.386571
# Running loss: 2.649546
# Running loss: 2.333368
# Running loss: 2.636184
# Running loss: 2.509830
# Running loss: 2.122413
# Running loss: 2.442576
# Running loss: 2.159629
# Running loss: 2.116731
# Running loss: 2.034033
# Running loss: 2.265094
# Running loss: 2.342981
# Running loss: 2.127399
# Running loss: 2.225623
# Running loss: 2.180666
# Running loss: 2.233166
# Running loss: 2.183400
# Running loss: 1.930933
# Running loss: 2.146892
# Running loss: 2.437937
# Running loss: 1.976028
# Running loss: 1.455844
# Running loss: 2.035066
# Running loss: 1.552544
# Running loss: 1.434418
# Running loss: 2.153850
# Running loss: 1.833710
# Running loss: 2.620797
# Running loss: 2.105217
# Running loss: 1.533452
# Running loss: 1.476126
# Running loss: 1.616773
# Running loss: 1.859804
# Running loss: 1.771165
# Running loss: 1.882866
# Running loss: 1.760831
# Running loss: 1.260787
# Running loss: 1.551973
# Running loss: 1.764614
# Running loss: 1.368833
# Running loss: 0.868832
# Running loss: 1.205116
# Running loss: 1.432853
# Running loss: 1.359997
# Running loss: 1.819148
# Running loss: 1.173434
# Running loss: 1.943443
# Running loss: 2.026231
# Running loss: 1.621960
# Running loss: 1.805028
# Running loss: 1.943026
# Running loss: 0.819496
# Running loss: 2.361920
# Running loss: 1.550518
# Running loss: 0.909341
# Running loss: 1.786111
# Running loss: 1.144123
# Running loss: 1.062678
# Running loss: 1.253281
# Running loss: 1.469047
# Running loss: 1.049077
# Running loss: 1.380928
# Running loss: 1.526593
# Running loss: 1.660167
# Running loss: 0.959596
# Running loss: 1.559469
# Running loss: 1.653880
# Running loss: 0.719686
# Running loss: 1.818357
# Running loss: 1.624253
# Running loss: 1.582080
# Running loss: 1.980078
# Running loss: 1.566825
# Running loss: 1.189750
# Running loss: 1.559252
# Running loss: 1.421343
# Running loss: 1.448685
# Running loss: 1.057005
# Running loss: 0.877844
# Running loss: 0.818003
# Running loss: 1.397015
# Running loss: 1.325055
# Running loss: 0.473739
# Running loss: 1.339701
# Running loss: 0.593283
# Running loss: 1.558211
# Running loss: 1.240796
# Running loss: 1.057521
# Running loss: 1.721772
# Running loss: 1.007978
# Running loss: 1.351701
# Running loss: 1.066584
# Running loss: 2.287154
# Running loss: 1.211948
# Running loss: 0.898445
# Running loss: 2.220366
# Running loss: 0.986331
# Running loss: 0.856716
# Running loss: 1.153251
# Running loss: 0.865398
# Running loss: 1.444880
# Running loss: 1.252432
# Running loss: 1.207722
# Running loss: 1.786597
# Running loss: 0.725255
# Running loss: 0.994660
# Running loss: 0.877279
# Running loss: 1.643396
# Running loss: 0.984276
# Running loss: 0.997666
# Running loss: 1.451695
# Running loss: 2.409994
# Running loss: 1.413283
# Running loss: 1.159853
# Running loss: 1.793663
# Running loss: 1.413977
# Running loss: 1.407659
# Running loss: 1.021401
# Running loss: 0.683756
# Running loss: 1.474925
# Running loss: 1.273594
# Running loss: 1.536108
# Running loss: 1.382586
# Running loss: 0.967150
# Running loss: 0.926776
# Running loss: 1.142030
# Running loss: 0.621878
# Running loss: 0.638953
# Running loss: 1.330986
# Running loss: 1.241660
# Running loss: 1.052844
# Running loss: 2.325405
# Running loss: 0.454827
# Running loss: 1.236594
# Running loss: 0.810326
# Running loss: 1.750926
# Running loss: 1.372978
# Running loss: 1.365293
# Running loss: 2.061950
# Running loss: 1.054419
# Running loss: 1.066121
# Running loss: 0.893618
# Running loss: 1.327730
# Running loss: 1.890940
# Running loss: 0.501919
# Running loss: 0.887837
# Running loss: 1.464176
# Running loss: 0.421745
# Running loss: 0.967568
# Running loss: 0.407611
# Running loss: 0.565184
# Running loss: 0.876845
# Running loss: 1.206961
# Running loss: 1.276859
# Running loss: 1.328668
# Running loss: 0.593941
# Running loss: 1.477120
# Running loss: 0.595635
# Running loss: 1.499300
# Running loss: 0.981571
# Running loss: 0.806504
# Running loss: 1.811505
# Running loss: 0.641911
# Running loss: 1.125507
# Running loss: 0.765553
# Running loss: 0.810822
# Running loss: 1.224088
# Running loss: 0.558450
# Running loss: 0.781240
# Running loss: 0.438377
# Running loss: 1.501938
# Running loss: 0.886683
# Running loss: 0.419934
# Running loss: 0.882666
# Running loss: 0.978705
# Running loss: 0.770569
# Running loss: 1.193475
# Running loss: 0.929455
# Running loss: 1.980191
# Running loss: 1.036179
# Running loss: 1.090682
# Running loss: 1.406499
# Running loss: 0.514713
# Running loss: 0.952649
# Running loss: 0.274884
# Running loss: 0.833337
# Running loss: 0.932545
# Running loss: 0.909896
# Running loss: 1.194249
# Running loss: 1.076761
# Running loss: 1.217113
# Running loss: 0.820099
# Running loss: 1.289966
# Running loss: 0.976901
# Running loss: 0.728821
# Running loss: 1.623387
# Running loss: 1.382543
# Running loss: 1.203381
# Running loss: 1.469415
# Running loss: 1.070333
# Running loss: 0.637156
# Running loss: 0.817409
# Running loss: 0.815881
# Running loss: 1.781301
# Running loss: 1.541335
# Running loss: 1.221820
# Running loss: 1.270292
# Running loss: 0.947219
# Running loss: 0.868374
# Running loss: 0.890412
# Running loss: 1.035199
# Running loss: 1.095282
# Running loss: 1.128252
# Running loss: 1.842079
# Running loss: 1.027020
# Running loss: 1.024021
# Running loss: 0.919890
# Running loss: 0.952976
# Running loss: 0.603877
# Running loss: 0.504334
# Running loss: 0.660089
# Running loss: 1.250220
# Running loss: 0.802898
# Running loss: 1.156212
# Running loss: 0.323062
# Running loss: 1.353820
# Running loss: 0.424594
# Running loss: 0.798946
# Running loss: 0.869862
# Running loss: 0.484863
# Running loss: 0.355355
# Running loss: 2.023589
# Running loss: 1.019386
# Running loss: 0.581057
# Running loss: 1.469795
# Running loss: 0.678789
# Running loss: 1.744980
# Running loss: 0.574861
# Running loss: 1.305218
# Running loss: 0.834076
# Running loss: 1.384096
# Running loss: 1.649603
# Running loss: 0.656710
# Running loss: 1.696308
# Running loss: 0.373798
# Running loss: 0.942786
# Running loss: 1.133919
# Running loss: 1.390906
# Running loss: 1.244252
# Running loss: 0.994147
# Running loss: 0.850308
# Running loss: 1.935325
# Running loss: 0.881067
# Running loss: 0.487852
# Running loss: 1.070563
# Running loss: 1.148340
# Running loss: 0.958824
# Running loss: 1.434011
# Running loss: 0.539403
# Running loss: 0.938490
# Running loss: 1.163442
# Running loss: 1.197782
# Running loss: 0.961545
# Running loss: 1.328567
# Running loss: 1.070417
# Running loss: 0.912058
# Running loss: 0.698539
# Running loss: 1.337584
# Running loss: 0.624454
# Running loss: 1.453927
# Running loss: 1.210696
# Running loss: 0.503859
# Running loss: 1.116414
# Running loss: 0.898898
# Running loss: 0.848530
# Running loss: 0.801676
# Running loss: 0.870151
# Running loss: 1.000238
# Running loss: 0.740558
# Running loss: 1.191493
# Running loss: 1.188562
# Running loss: 0.739817
# Running loss: 1.144464
# Running loss: 0.559405
# Running loss: 0.669679
# Running loss: 0.981163
# Running loss: 1.154365
# Running loss: 1.792434
# Running loss: 0.729926
# Running loss: 0.399849
# Running loss: 1.036369
# Running loss: 0.933840
# Running loss: 1.352977
# Running loss: 0.653889
# Running loss: 1.034036
# Running loss: 0.949943
# Running loss: 1.233081
# Running loss: 1.363225
# Running loss: 0.282347
# Running loss: 0.804676
# Running loss: 1.227388
# Running loss: 0.461801
# Running loss: 2.062933
# Running loss: 1.179729
# Running loss: 0.751354
# Running loss: 0.944815
# Running loss: 1.091354
# Running loss: 1.131871
# Running loss: 1.272318
# Running loss: 1.219715
# Running loss: 1.440817
# Running loss: 1.187292
# Running loss: 0.667038
# Running loss: 1.044205
# Running loss: 0.793692
# Running loss: 1.076312
# Running loss: 0.920063
# Running loss: 1.109446
# Running loss: 1.407749
# Running loss: 1.523309
# Running loss: 1.044298
# Running loss: 1.592376
# Running loss: 1.082104
# Running loss: 1.015483
# Running loss: 0.585272
# Running loss: 1.259999
# Running loss: 1.330048
# Running loss: 1.864643
# Running loss: 0.745181
# Running loss: 0.705077
# Running loss: 0.969651
# Running loss: 1.016020
# Running loss: 1.172583
# Running loss: 0.338389
# Running loss: 0.864353
# Running loss: 0.871999
# Running loss: 0.716805
# Running loss: 0.722052
# Running loss: 0.907608
# Running loss: 1.964545
# Running loss: 1.700445
# Running loss: 0.584889
# Running loss: 0.964814
# Running loss: 0.976266
# Running loss: 0.822144
# Running loss: 1.083460
# Running loss: 1.634723
# Running loss: 1.533078
# Running loss: 1.174851
# Running loss: 2.443260
# Running loss: 1.843555
# Running loss: 1.057271
# Running loss: 0.557457
# Running loss: 0.954915
# Running loss: 0.983764
# Running loss: 1.004981
# Running loss: 0.916332
# Running loss: 1.980171
# Running loss: 1.148611
# Running loss: 1.447375
# Running loss: 1.357582
# Running loss: 0.918450
# Running loss: 1.271703
# Running loss: 1.492871
# Running loss: 1.334733
# Running loss: 0.686135
# Running loss: 1.074109
# Running loss: 1.145083
# Running loss: 0.583779
# Running loss: 1.373000
# Running loss: 1.256151
# Running loss: 0.531991
# Running loss: 1.761771
# Running loss: 1.036768
# Running loss: 1.302500
# Running loss: 0.407397
# Running loss: 1.335672
# Running loss: 0.864752
# Running loss: 0.724205
# Running loss: 0.705174
# Running loss: 0.908224
# Running loss: 0.586218
# Running loss: 1.102460
# Running loss: 0.394752
# Running loss: 0.890083
# Running loss: 2.296270
# Running loss: 0.499171
# Running loss: 1.611188
# Running loss: 0.990057
# Running loss: 1.198136
# Running loss: 0.981401
# Running loss: 1.237816
# Running loss: 1.351037
# Running loss: 0.982779
# Running loss: 0.782496
# Running loss: 0.896308
# Running loss: 0.575953
# Running loss: 1.654104
# Running loss: 0.951323
# Running loss: 0.874807
# Running loss: 1.687700
# Running loss: 1.021877
# Running loss: 1.321838
# Running loss: 1.142905
# Running loss: 0.887766
# Running loss: 1.121258
# Running loss: 1.120044
# Running loss: 1.585450
# Running loss: 0.935339
# Running loss: 1.034501
# Running loss: 1.076611
# Running loss: 1.331534
# Running loss: 1.178608
# Running loss: 0.600305
# Running loss: 1.098885
# Running loss: 0.774834
# Running loss: 1.643170
# Running loss: 1.316028
# Running loss: 1.192835
# Running loss: 0.531230
# Running loss: 1.916984
# Running loss: 0.923407
# Running loss: 1.825951
# Running loss: 0.773886
# Running loss: 1.193795
# Running loss: 0.907524
# Running loss: 0.344418
# Running loss: 1.174980
# Running loss: 0.923818
# Running loss: 0.821198
# Running loss: 0.854064
# Running loss: 0.413214
# Running loss: 1.680480
# Running loss: 0.885177
# Running loss: 1.116827
# Running loss: 2.110041
# Running loss: 1.275346
# Running loss: 0.777611
# Running loss: 1.110887
# Running loss: 0.538621
# Running loss: 1.023980
# Running loss: 1.785110
# Running loss: 0.488265
# Running loss: 0.583436
# Running loss: 1.076090
# Running loss: 1.479408
# Running loss: 1.891114
# Running loss: 0.779805
# Running loss: 0.937102
# Running loss: 0.820082
# Running loss: 1.130693
# Running loss: 0.941172
# Running loss: 0.947771
# Running loss: 0.943012
# Running loss: 0.730889
# Running loss: 2.183108
# Running loss: 1.167664
# Running loss: 0.712491
# Running loss: 1.365280
# Running loss: 0.758753
# Running loss: 1.317409
# Running loss: 0.781328
# Running loss: 0.629710
# Running loss: 0.743056
# Running loss: 1.246922
# Running loss: 0.992578
# Running loss: 0.622044
# Running loss: 1.206477
# Running loss: 1.263324
# Running loss: 1.015949
# Running loss: 0.810858
# Running loss: 0.971004
# Running loss: 1.793944
# Running loss: 0.895284
# Running loss: 1.112033
# Running loss: 1.313058
# Running loss: 1.001833
# Running loss: 0.753864
# Running loss: 1.002047
# Running loss: 1.267431
# Running loss: 1.122429
# Running loss: 1.149106
# Running loss: 0.593119
# Running loss: 0.317163
# Running loss: 0.976998
# Running loss: 1.099363
# Running loss: 1.576461
# Running loss: 0.863341
# Running loss: 1.023956
# Running loss: 1.385568
# Running loss: 1.312261
# Running loss: 1.002655
# Running loss: 1.152874
# Running loss: 0.945786
# Running loss: 0.634960
# Running loss: 1.381161
# Running loss: 1.284247
# Running loss: 1.084958
# Running loss: 0.722368
# Running loss: 1.879501
# Running loss: 1.147476
# Running loss: 1.309986
# Running loss: 0.603437
# Running loss: 1.320590
# Running loss: 1.000370
# Running loss: 1.514837
# Running loss: 1.276506
# Running loss: 1.058661
# Running loss: 1.016200
# Running loss: 2.128067
# Running loss: 0.945020
# Running loss: 0.749175
# Running loss: 1.428491
# Running loss: 0.845352
# Running loss: 1.088936
# Running loss: 0.936263
# Running loss: 1.202359
# Running loss: 2.070425
# Running loss: 1.126813
# Running loss: 1.044717
# Running loss: 1.794799
# Running loss: 0.940587
# Running loss: 1.495751
# Running loss: 2.060827
# Running loss: 1.121691
# Running loss: 1.335597
# Running loss: 1.107336
# Running loss: 1.024397
# Running loss: 1.220215
# Running loss: 0.856612
# Running loss: 0.890550
# Running loss: 1.260942
# Running loss: 0.988751
# Running loss: 1.065170
# Running loss: 0.720747
# Running loss: 1.300843
# Running loss: 0.963671
# Running loss: 1.347768
# Running loss: 1.403919
# Running loss: 1.636870
# Running loss: 0.901253
# Running loss: 0.495993
# Running loss: 1.065983
# Running loss: 1.369456
# Running loss: 0.575373
# Running loss: 0.718694
# Running loss: 0.684845
# Running loss: 1.229406
# Running loss: 1.494238
# Running loss: 0.641415
# Running loss: 0.522709
# Running loss: 0.453984
# Running loss: 1.434730
# Running loss: 0.322311
# Running loss: 0.740963
# Running loss: 1.415587
# Running loss: 1.086656
# Running loss: 1.140068
# Running loss: 0.788308
# Running loss: 1.024510
# Running loss: 0.939938
# Running loss: 1.167114
# Running loss: 0.451397
# Running loss: 1.872862
# Running loss: 1.589800
# Running loss: 1.516016
# Running loss: 0.587563
# Running loss: 1.180265
# Running loss: 0.616115
# Running loss: 0.522217
# Running loss: 1.130010
# Running loss: 1.611587
# Running loss: 1.768459
# Running loss: 0.904299
# Running loss: 0.462768
# Running loss: 0.645618
# Running loss: 0.750636
# Running loss: 0.485528
# Running loss: 1.023165
# Running loss: 1.465743
# Running loss: 0.809664
# Running loss: 1.303932
# Running loss: 1.004187
# Running loss: 0.791346
# Running loss: 0.476874
# Running loss: 0.750633
# Running loss: 0.483727
# Running loss: 1.232877
# Running loss: 0.759852
# Running loss: 0.407914
# Running loss: 1.007183
# Running loss: 1.377694
# Running loss: 1.068391
# Running loss: 0.354544
# Running loss: 1.194748
# Running loss: 0.347157
# Running loss: 0.878534
# Running loss: 1.327769
# Running loss: 1.600118
# Running loss: 0.498628
# Running loss: 1.579136
# Running loss: 0.658736
# Running loss: 0.490259
# Running loss: 0.956907
# Running loss: 1.423877
# Running loss: 0.525295
# Running loss: 1.313704
# Running loss: 1.375587
# Running loss: 1.308205
# Running loss: 1.844838
# Running loss: 1.211817
# Running loss: 1.444075
# Running loss: 1.003252
# Running loss: 0.969433
# Running loss: 0.752486
# Running loss: 0.772347
# Running loss: 0.942978
# Running loss: 1.281068
# Running loss: 0.484075
# Running loss: 0.883582
# Running loss: 1.767756
# Running loss: 0.976379
# Running loss: 2.045290
# Running loss: 0.728155
# Running loss: 1.755038
# Running loss: 1.559801
# Running loss: 1.552953
# Running loss: 0.881706
# Running loss: 0.749475
# Running loss: 0.852818
# Running loss: 1.088580
# Running loss: 0.423234
# Running loss: 0.827515
# Running loss: 1.715417
# Running loss: 1.195029
# Running loss: 1.028943
# Running loss: 0.742146
# Running loss: 1.145898
# Running loss: 0.725263
# Running loss: 1.160577
# Running loss: 0.987337
# Running loss: 1.027375
# Running loss: 0.812266
# Running loss: 0.651525
# Running loss: 0.677236
# Running loss: 1.460275
# Running loss: 0.935643
# Running loss: 0.853038
# Running loss: 0.608307
# Running loss: 0.963129
# Running loss: 0.866229
# Running loss: 1.108179
# Running loss: 0.723238
# Running loss: 0.259555
# Running loss: 0.937788
# Running loss: 0.876877
# Running loss: 1.197493
# Running loss: 0.557770
# Running loss: 1.075661
# Running loss: 0.975816
# Running loss: 0.604240
# Running loss: 1.182823
# Running loss: 0.574233
# Running loss: 0.607265
# Running loss: 0.587673
# Running loss: 0.889073
# Running loss: 0.542747
# Running loss: 0.784845
# Running loss: 0.831522
# Running loss: 0.450212
# Running loss: 1.049481
# Running loss: 0.319350
# Running loss: 1.680248
# Running loss: 1.920614
# Running loss: 0.786705
# Running loss: 1.223956
# Running loss: 1.113261
# Running loss: 1.330397
# Running loss: 0.912434
# Running loss: 0.997630
# Running loss: 0.867645
# Running loss: 0.822566
# Running loss: 0.870151
# Running loss: 0.536286
# Running loss: 1.162655
# Running loss: 1.730480
# Running loss: 1.308986
# Running loss: 0.803476
# Running loss: 1.339155
# Running loss: 0.541475
# Running loss: 0.322841
# Running loss: 0.850441
# Running loss: 1.196041
# Running loss: 1.233877
# Running loss: 1.825635
# Running loss: 0.838595
# Running loss: 0.825471
# Running loss: 1.622376
# Running loss: 0.770098
# Running loss: 1.344072
# Running loss: 0.982220
# Running loss: 0.904058
# Running loss: 1.601691
# Running loss: 0.674296
# Running loss: 0.789053
# Running loss: 0.906589
# Running loss: 0.898006
# Running loss: 0.988871
# Running loss: 1.235988
# Running loss: 0.860579
# Running loss: 0.555563
# Running loss: 1.127686
# Running loss: 1.972363
# Running loss: 0.972581
# Running loss: 0.661874
# Running loss: 0.934096
# Running loss: 0.478620
# Running loss: 0.685216
# Running loss: 0.644315
# Running loss: 0.828616
# Running loss: 0.762527
# Running loss: 1.328549
# Running loss: 0.280942
# Running loss: 1.648184
# Running loss: 0.767017
# Running loss: 1.395467
# Running loss: 1.303774
# Running loss: 0.980997
# Running loss: 1.511520
# Running loss: 0.617888
# Running loss: 0.606773
# Running loss: 0.569450
# Running loss: 1.022953
# Running loss: 1.020894
# Running loss: 0.837071
# Running loss: 0.615721
# Running loss: 0.638551
# Running loss: 0.685082
# Running loss: 1.278628
# Running loss: 1.172725
# Running loss: 0.793942
# Running loss: 0.708249
# Running loss: 0.603072
# Running loss: 0.892859
# Running loss: 1.173419
# Running loss: 0.887070
# Running loss: 1.152496
# Running loss: 1.130712
# Running loss: 0.851157
# Running loss: 1.123463
# Running loss: 0.275544
# Running loss: 0.350929
# Running loss: 0.959100
# Running loss: 1.003218
# Running loss: 0.469384
# Running loss: 0.533783
# Running loss: 0.684382
# Running loss: 1.274155
# Running loss: 1.050189
# Running loss: 0.716594
# Running loss: 0.991478
# Running loss: 0.614837
# Running loss: 1.584915
# Running loss: 0.813360
# Running loss: 1.029246
# Running loss: 0.854979
# Running loss: 0.414073
# Running loss: 0.686921
# Running loss: 1.736343
# Running loss: 0.856905
# Running loss: 0.465423
# Running loss: 0.195034
# Running loss: 0.616436
# Running loss: 0.531950
# Running loss: 1.117285
# Running loss: 1.390495
# Running loss: 0.883892
# Running loss: 1.427806
# Running loss: 0.648268
# Running loss: 0.955046
# Running loss: 0.574454
# Running loss: 0.834714
# Running loss: 1.020034
# Running loss: 0.762724
# Running loss: 0.748663
# Running loss: 0.512100
# Running loss: 1.319209
# Running loss: 1.297962
# Running loss: 0.889855
# Running loss: 1.422063
# Running loss: 1.459985
# Running loss: 0.598839
# Running loss: 0.914725
# Running loss: 0.832850
# Running loss: 0.330373
# Running loss: 0.900463
# Running loss: 0.197227
# Running loss: 1.679358
# Running loss: 0.810209
# Running loss: 1.237759
# Running loss: 0.775134
# Running loss: 0.493269
# Running loss: 0.918337
# Running loss: 0.411138
# Running loss: 1.566920
# Running loss: 0.284951
# Running loss: 0.523254
# Running loss: 0.805984
# Running loss: 1.298903
# Running loss: 1.347943
# Running loss: 1.365524
# Running loss: 1.340044
# Running loss: 1.736772
# Running loss: 1.335306
# Running loss: 1.127664
# Running loss: 2.041349
# Running loss: 0.854821
# Running loss: 1.360538
# Running loss: 1.356048
# Running loss: 0.929156
# Running loss: 1.294437
# Running loss: 0.887512
# Running loss: 0.751406
# Running loss: 0.688162
# Running loss: 1.456867
# Running loss: 0.886892
# Running loss: 1.232769
# Running loss: 0.968257
# Running loss: 0.700077
# Running loss: 1.028804
# Running loss: 1.219715
# Running loss: 0.983220
# Running loss: 1.131949
# Running loss: 0.519535
# Running loss: 0.867836
# Running loss: 0.765134
# Running loss: 1.342167
# Running loss: 2.126514
# Running loss: 1.127936
# Running loss: 0.899163
# Running loss: 1.062478
# Running loss: 1.113830
# Running loss: 0.638420
# Running loss: 1.183334
# Running loss: 1.368640
# Running loss: 0.685783
# Running loss: 0.747412
# Running loss: 1.782698
# Running loss: 1.086768
# Running loss: 0.503345
# Running loss: 0.455288
# Running loss: 0.695403
# Running loss: 0.563332
# Running loss: 1.478601
# Running loss: 0.394938
# Running loss: 0.777052
# Running loss: 0.324332
# Running loss: 0.701802
# Running loss: 1.212919
# Running loss: 0.498704
# Running loss: 1.004350
# Running loss: 0.567467
# Running loss: 0.978436
# Running loss: 1.464037
# Running loss: 0.710366
# Running loss: 1.072722
# Running loss: 1.204170
# Running loss: 1.281778
# Running loss: 1.546977
# Running loss: 0.757486
# Running loss: 1.424310
# Running loss: 0.873187
# Running loss: 1.817736
# Running loss: 0.185079
# Running loss: 0.793703
# Running loss: 1.876410
# Running loss: 0.819959
# Running loss: 0.890999
# Running loss: 1.208662
# Running loss: 0.423545
# Running loss: 0.622041
# Running loss: 1.857057
# Running loss: 0.528808
# Running loss: 0.527188
# Running loss: 0.918873
# Running loss: 0.821647
# Running loss: 0.504357
# Running loss: 0.996205
# Running loss: 1.470168
# Running loss: 1.284054
# Running loss: 0.998590
# Running loss: 1.170719
# Running loss: 1.544146
# Running loss: 1.498528
# Running loss: 0.734546
# Running loss: 0.880826
# Running loss: 0.632481
# Running loss: 1.545640
# Running loss: 0.331687
# Running loss: 1.277843
# Running loss: 1.337182
# Running loss: 0.965962
# Running loss: 0.957512
# Running loss: 1.446577
# Running loss: 1.432807
# Running loss: 1.371388
# Running loss: 0.970580
# Running loss: 0.914412
# Running loss: 1.125284
# Running loss: 0.394175
# Running loss: 0.593137
# Running loss: 1.195529
# Running loss: 1.163289
# Running loss: 0.961188
# Running loss: 0.793348
# Running loss: 1.514364
# Running loss: 1.307559
# Running loss: 1.936708
# Running loss: 1.637205
# Running loss: 0.623598
# Running loss: 0.614790
# Running loss: 1.144585
# Running loss: 1.268418
# Running loss: 1.599714
# Running loss: 0.835696
# Running loss: 1.144803
# Running loss: 0.757098
# Running loss: 0.928929
# Running loss: 0.698009
# Running loss: 0.624278
# Running loss: 1.335666
# Running loss: 0.846694
# Running loss: 0.795265
# Running loss: 1.484359
# Running loss: 0.569703
# Running loss: 1.098496
# Running loss: 0.915266
# Running loss: 1.544758
# Running loss: 1.392863
# Running loss: 0.242038
# Running loss: 0.598275
# Running loss: 0.594024
# Running loss: 0.935413
# Running loss: 1.666932
# Running loss: 0.844082
# Running loss: 1.321458
# Running loss: 2.170533
# Running loss: 0.629149
# Running loss: 1.967140
# Running loss: 0.534764
# Running loss: 0.583519
# Running loss: 0.818524
# Running loss: 1.066448
# Running loss: 1.004589
# Running loss: 0.549280
# Running loss: 0.469421
# Running loss: 0.555360
# Running loss: 0.409978
# Running loss: 0.958556
# Running loss: 1.370692
# Running loss: 1.192725
# Running loss: 1.869355
# Running loss: 0.938015
# Running loss: 0.827393
# Running loss: 1.266860
# Running loss: 0.918010
# Running loss: 0.968205
# Running loss: 1.081517
# Running loss: 0.409305
# Running loss: 0.855255
# Running loss: 1.445671
# Running loss: 1.016340
# Running loss: 0.696310
# Running loss: 1.247051
# Running loss: 0.928844
# Running loss: 0.885688
# Running loss: 0.523256
# Running loss: 1.105386
# Running loss: 1.078668
# Running loss: 1.518188
# Running loss: 0.560629
# Running loss: 1.240186
# Running loss: 1.016612
# Running loss: 0.597359
# Running loss: 1.523450
# Running loss: 0.624848
# Running loss: 0.890616
# Running loss: 1.739131
# Running loss: 0.388610
# Running loss: 1.068632
# Running loss: 0.675715
# Running loss: 1.246734
# Running loss: 1.038223
# Running loss: 1.002713
# Running loss: 1.105200
# Running loss: 0.805540
# Running loss: 1.051313
# Running loss: 1.679080
# Running loss: 0.776023
# Running loss: 1.814922
# Running loss: 1.122764
# Running loss: 1.095662
# Running loss: 1.092127
# Running loss: 1.008259
# Running loss: 0.993817
# Running loss: 1.508124
# Running loss: 0.898544
# Running loss: 0.812368
# Running loss: 1.394584
# Running loss: 0.824796
# Running loss: 0.940976
# Running loss: 0.929268
# Running loss: 0.947434
# Running loss: 1.016917
# Running loss: 0.622979
# Running loss: 1.226420
# Running loss: 1.140305
# Running loss: 0.540219
# Running loss: 0.507515
# Running loss: 1.527194
# Running loss: 1.438651
# Running loss: 0.700290
# Running loss: 1.704385
# Running loss: 0.372069
# Running loss: 0.763474
# Running loss: 0.547468
# Running loss: 0.765180
# Running loss: 1.662834
# Running loss: 0.854507
# Running loss: 0.606606
# Running loss: 1.074428
# Running loss: 0.997768
# Running loss: 1.138396
# Running loss: 0.960522
# Running loss: 1.157722
# Running loss: 1.116640
# Running loss: 0.902394
# Running loss: 1.085320
# Running loss: 0.876050
# Running loss: 0.937165
# Running loss: 0.561504
# Running loss: 1.087053
# Running loss: 1.185232
# Running loss: 1.270522
# Running loss: 0.698111
# Running loss: 0.627727
# Running loss: 1.172815
# Running loss: 0.749983
# Running loss: 1.809360
# Running loss: 0.655322
# Running loss: 0.482592
# Running loss: 0.442542
# Running loss: 0.609866
# Running loss: 1.022704
# Running loss: 1.048618
# Running loss: 1.125034
# Running loss: 1.132252
# Running loss: 0.545849
# Running loss: 0.213530
# Running loss: 0.987317
# Running loss: 0.754755
# Running loss: 1.612884
# Running loss: 0.505772
# Running loss: 0.415480
# Running loss: 0.732752
# Running loss: 0.326069
# Running loss: 0.887238
# Running loss: 1.077469
# Running loss: 0.821880
# Running loss: 0.690617
# Running loss: 0.419326
# Running loss: 1.026699
# Running loss: 0.967636
# Running loss: 0.608701
# Running loss: 0.532999
# Running loss: 0.860312
# Running loss: 1.011011
# Running loss: 0.348924
# Running loss: 0.745158
# Running loss: 0.085483
# Running loss: 0.738114
# Running loss: 2.488844
# Running loss: 1.493570
# Running loss: 0.773882
# Running loss: 0.776509
# Running loss: 0.335137
# Running loss: 0.919463
# Running loss: 0.850933
# Running loss: 0.491628
# Running loss: 0.865229
# Running loss: 1.322676
# Running loss: 0.675897
# Running loss: 0.836224
# Running loss: 0.727928
# Running loss: 0.321564
# Running loss: 1.313319
# Running loss: 0.920046
# Running loss: 0.319833
# Running loss: 2.022583
# Running loss: 1.281066
# Running loss: 0.893692
# Running loss: 0.913448
# Running loss: 0.648482
# Running loss: 1.259310
# Running loss: 1.455620
# Running loss: 1.008729
# Running loss: 0.899983
# Running loss: 1.050232
# Running loss: 1.053608
# Running loss: 1.130805
# Running loss: 1.036001
# Running loss: 0.347149
# Running loss: 1.131247
# Running loss: 0.690889
# Running loss: 0.884343
# Running loss: 0.753273
# Running loss: 2.121736
# Running loss: 0.917763
# Running loss: 1.908571
# Running loss: 1.271856
# Running loss: 1.093799
# Running loss: 0.565098
# Running loss: 0.366072
# Running loss: 0.778422
# Running loss: 0.434701
# Running loss: 1.049959
# Running loss: 1.155301
# Running loss: 1.305554
# Running loss: 1.095515
# Running loss: 0.645167
# Running loss: 1.393160
# Running loss: 1.087753
# Running loss: 0.725289
# Running loss: 0.735765
# Running loss: 1.123696
# Running loss: 0.876927
# Running loss: 1.314572
# Running loss: 1.293828
# Running loss: 1.714545
# Running loss: 0.915193
# Running loss: 0.930636
# Running loss: 1.284879
# Running loss: 1.433395
# Running loss: 0.602799
# Running loss: 2.194384
# Running loss: 1.218023
# Running loss: 1.194396
# Running loss: 1.012432
# Running loss: 1.093430
# Running loss: 1.455005
# Running loss: 1.053778
# Running loss: 0.797933
# Running loss: 0.917102
# Running loss: 0.958265
# Running loss: 1.409470
# Running loss: 1.153494
# Running loss: 0.358941
# Running loss: 1.088242
# Running loss: 0.944909
# Running loss: 0.850067
# Running loss: 1.066993
# Running loss: 1.097760
# Running loss: 1.664028
# Running loss: 1.303220
# Running loss: 1.142727
# Running loss: 0.725414
# Running loss: 0.882625
# Running loss: 1.012755
# Running loss: 0.764544
# Running loss: 1.034631
# Running loss: 0.789972
# Running loss: 1.097900
# Running loss: 1.158426
# Running loss: 0.933654
# Running loss: 0.981542
# Running loss: 0.692399
# Running loss: 0.914410
# Running loss: 0.398731
# Running loss: 0.726259
# Running loss: 0.861072
# Running loss: 0.496645
# Running loss: 0.627797
# Running loss: 1.342719
# Running loss: 0.255145
# Running loss: 0.938076
# Running loss: 0.340196
# Running loss: 0.673842
# Running loss: 1.334577
# Running loss: 0.959102
# Running loss: 0.918075
# Running loss: 0.894124
# Running loss: 0.984512
# Running loss: 0.862081
# Running loss: 1.395424
# Running loss: 0.460661
# Running loss: 1.296172
# Running loss: 1.442731
# Running loss: 0.851157
# Running loss: 1.153708
# Running loss: 0.792594
# Running loss: 0.594276
# Running loss: 0.648254
# Running loss: 0.677333
# Running loss: 1.648926
# Running loss: 1.355279
# Running loss: 0.994257
# Running loss: 1.090320
# Running loss: 0.719365
# Running loss: 0.267009
# Running loss: 1.073660
# Running loss: 0.531910
# Running loss: 0.710558
# Running loss: 0.911062
# Running loss: 1.071323
# Running loss: 0.968920
# Running loss: 1.353547
# Running loss: 1.158366
# Running loss: 0.439325
# Running loss: 1.246848
# Running loss: 0.654027
# Running loss: 0.441146
# Running loss: 1.348444
# Running loss: 1.236946
# Running loss: 0.849633
# Running loss: 0.797869
# Running loss: 0.380673
# Running loss: 0.847780
# Running loss: 1.365933
# Running loss: 0.487441
# Running loss: 0.758879
# Running loss: 1.136356
# Running loss: 1.146733
# Running loss: 1.026957
# Running loss: 0.358207
# Running loss: 0.893638
# Running loss: 0.815471
# Running loss: 1.343908
# Running loss: 0.670931
# Running loss: 0.327553
# Running loss: 0.347229
# Running loss: 0.837060
# Running loss: 0.652153
# Running loss: 1.507141
# Running loss: 0.301564
# Running loss: 1.136598
# Running loss: 1.363601
# Running loss: 1.321738
# Running loss: 0.805687
# Running loss: 1.597439
# Running loss: 1.016510
# Running loss: 0.754572
# Running loss: 1.086822
# Running loss: 1.050999
# Running loss: 1.088001
# Running loss: 1.046884
# Running loss: 0.901685
# Running loss: 0.955371
# Running loss: 0.580982
# Running loss: 1.005580
# Running loss: 1.330359
# Running loss: 1.098498
# Running loss: 0.877045
# Running loss: 0.922641
# Running loss: 1.040772
# Running loss: 0.526031
# Running loss: 0.992531
# Running loss: 0.675630
# Running loss: 1.229587
# Running loss: 0.775876
# Running loss: 1.585793
# Running loss: 1.181170
# Running loss: 0.898863
# Running loss: 0.833448
# Running loss: 1.005623
# Running loss: 1.158179
# Running loss: 0.891010
# Running loss: 1.144195
# Running loss: 0.770088
# Running loss: 1.326748
# Running loss: 1.347825
# Running loss: 1.495820
# Running loss: 1.315019
# Running loss: 0.346832
# Running loss: 0.525645
# Running loss: 0.507552
# Running loss: 0.707662
# Running loss: 1.566387
# Running loss: 1.015695
# Running loss: 1.390154
# Running loss: 0.751438
# Running loss: 0.674054
# Running loss: 0.641353
# Running loss: 0.517270
# Running loss: 0.263362
# Running loss: 0.875933
# Running loss: 0.921373
# Running loss: 0.559445
# Running loss: 0.949090
# Running loss: 1.118477
# Running loss: 1.696121
# Running loss: 0.635993
# Running loss: 0.916804
# Running loss: 0.787958
# Running loss: 1.234816
# Running loss: 1.053531
# Running loss: 0.316471
# Running loss: 0.818127
# Running loss: 0.930585
# Running loss: 0.915396
# Running loss: 2.062752
# Running loss: 0.035613
# Running loss: 0.268331
# Running loss: 1.936950
# Running loss: 2.138880
# Running loss: 1.165658
# Running loss: 0.708902
# Running loss: 1.680111
# Running loss: 0.928480
# Running loss: 0.262169
# Running loss: 1.427636
# Running loss: 1.017453
# Running loss: 0.386917
# Running loss: 0.784499
# Running loss: 0.691068
# Running loss: 0.980866
# Running loss: 1.044481
# Running loss: 0.522086
# Running loss: 1.047957
# Running loss: 1.166130
# Running loss: 0.773532
# Running loss: 0.722921
# Running loss: 1.393364
# Running loss: 0.412913
# Running loss: 0.707509
# Running loss: 1.066769
# Running loss: 0.938651
# Running loss: 1.223987
# Running loss: 0.216631
# Running loss: 0.925194
# Running loss: 0.709422
# Running loss: 0.358562
# Running loss: 1.677567
# Running loss: 1.040968
# Running loss: 1.237779
# Running loss: 1.267113
# Running loss: 0.357041
# Running loss: 1.075741
# Running loss: 0.986794
# Running loss: 1.277409
# Running loss: 0.689412
# Running loss: 1.075013
# Running loss: 1.075203
# Running loss: 1.678974
# Running loss: 1.010204
# Running loss: 0.939822
# Running loss: 1.107062
# Running loss: 0.855796
# Running loss: 0.851844
# Running loss: 1.149386
# Running loss: 0.392105
# Running loss: 1.122347
# Running loss: 1.742794
# Running loss: 1.007777
# Running loss: 1.077384
# Running loss: 1.079785
# Running loss: 1.246620
# Running loss: 0.437979
# Running loss: 0.642077
# Running loss: 1.181444
# Running loss: 0.508161
# Running loss: 1.225605
# Running loss: 0.739771
# Running loss: 0.775030
# Running loss: 1.364832
# Running loss: 0.781129
# Running loss: 0.979650
# Running loss: 1.047329
# Running loss: 1.297244
# Running loss: 0.901704
# Running loss: 1.511343
# Running loss: 1.111837
# Running loss: 0.892947
# Running loss: 1.103290
# Running loss: 0.686289
# Running loss: 0.695130
# Running loss: 0.631356
# Running loss: 0.956469
# Running loss: 0.785596
# Running loss: 0.824935
# Running loss: 0.413081
# Running loss: 1.280736
# Running loss: 1.253517
# Running loss: 1.365150
# Running loss: 1.272258
# Running loss: 1.236559
# Running loss: 0.957056
# Running loss: 1.813985
# Running loss: 0.782541
# Running loss: 0.809961
# Running loss: 0.920879
# Running loss: 0.819713
# Running loss: 0.906879
# Running loss: 0.515923
# Running loss: 0.727121
# Running loss: 0.624386
# Running loss: 1.229138
# Running loss: 0.652327
# Running loss: 0.871195
# Running loss: 0.789103
# Running loss: 1.383944
# Running loss: 0.598059
# Running loss: 0.932981
# Running loss: 1.195840
# Running loss: 0.742786
# Running loss: 0.613285
# Running loss: 1.001499
# Running loss: 0.656340
# Running loss: 0.367246
# Running loss: 2.039472
# Running loss: 1.727980
# Running loss: 0.159055
# Running loss: 0.930691
# Running loss: 0.675163
# Running loss: 0.525781
# Running loss: 0.689988
# Running loss: 1.382739
# Running loss: 0.909737
# Running loss: 1.528586
# Running loss: 1.168014
# Running loss: 1.302246
# Running loss: 0.480011
# Running loss: 1.009981
# Running loss: 0.708834
# Running loss: 1.089978
# Running loss: 0.668235
# Running loss: 1.119910
# Running loss: 1.227747
# Running loss: 0.494353
# Running loss: 0.926003
# Running loss: 1.351929
# Running loss: 0.630752
# Running loss: 0.590939
# Running loss: 1.068874
# Running loss: 0.575749
# Running loss: 0.113870
# Running loss: 0.263890
# Running loss: 1.172494
# Running loss: 0.723483
# Running loss: 2.040341
# Running loss: 1.745124
# Running loss: 0.242985
# Running loss: 0.921120
# Running loss: 0.419968
# Running loss: 0.637189
# Running loss: 0.887655
# Running loss: 0.535979
# Running loss: 0.974483
# Running loss: 1.203280
# Running loss: 1.152286
# Running loss: 0.523297
# Running loss: 0.711456
# Running loss: 1.046795
# Running loss: 1.064774
# Running loss: 0.372720
# Running loss: 1.466644
# Running loss: 1.261775
# Running loss: 0.710505
# Running loss: 0.824762
# Running loss: 0.460790
# Running loss: 1.379423
# Running loss: 1.618107
# Running loss: 0.345783
# Running loss: 1.643631
# Running loss: 1.084635
# Running loss: 0.793567
# Running loss: 0.830572
# Running loss: 1.300234
# Running loss: 1.070299
# Running loss: 1.221009
# Running loss: 1.088779
# Running loss: 0.433603
# Running loss: 1.154336
# Running loss: 0.225015
# Running loss: 1.487773
# Running loss: 1.361775
# Running loss: 0.966324
# Running loss: 0.750645
# Running loss: 1.334191
# Running loss: 0.456215
# Running loss: 0.889506
# Running loss: 0.546747
# Running loss: 0.274857
# Running loss: 0.854336
# Running loss: 0.939542
# Running loss: 0.866967
# Running loss: 1.186840
# Running loss: 0.363172
# Running loss: 1.275139
# Running loss: 1.137510
# Running loss: 1.115108
# Running loss: 0.284030
# Running loss: 2.618499
# Running loss: 0.799192
# Running loss: 1.240148
# Running loss: 0.910951
# Running loss: 1.504075
# Running loss: 0.647870
# Running loss: 1.450512
# Running loss: 0.441065
# Running loss: 1.044649
# Running loss: 1.106984
# Running loss: 0.583924
# Running loss: 0.415526
# Running loss: 0.492843
# Running loss: 1.466626
# Running loss: 0.905277
# Running loss: 0.877830
# Running loss: 1.683825
# Running loss: 1.164478
# Running loss: 1.480125
# Running loss: 0.886883
# Running loss: 0.985533
# Running loss: 1.289734
# Running loss: 0.931399
# Running loss: 0.917750
# Running loss: 1.061532
# Running loss: 1.182419
# Running loss: 0.352312
# Running loss: 0.630686
# Running loss: 0.784354
# Running loss: 1.282701
# Running loss: 0.952321
# Running loss: 1.143992
# Running loss: 0.372271
# Running loss: 0.954581
# Running loss: 1.143528
# Running loss: 0.519736
# Running loss: 0.745298
# Running loss: 0.846775
# Running loss: 0.919171
# Running loss: 0.532849
# Running loss: 1.507727
# Running loss: 1.188015
# Running loss: 1.334972
# Running loss: 1.657175
# Running loss: 1.290365
# Running loss: 1.025378
# Running loss: 0.421984
# Running loss: 1.302642
# Running loss: 0.852035
# Running loss: 0.686921
# Running loss: 1.112779
# Running loss: 1.679969
# Running loss: 0.832826
# Running loss: 1.251166
# Running loss: 0.641147
# Running loss: 1.207582
# Running loss: 1.058469
# Running loss: 0.830519
# Running loss: 0.665269
# Running loss: 0.751395
# Running loss: 0.513215
# Running loss: 0.436129
# Running loss: 0.927893
# Running loss: 0.522337
# Running loss: 0.609343
# Running loss: 0.767695
# Running loss: 0.618245
# Running loss: 0.530890
# Running loss: 0.777447
# Running loss: 1.320512
# Running loss: 0.943428
# Running loss: 0.757180
# Running loss: 1.213978
# Running loss: 0.843922
# Running loss: 1.102728
# Running loss: 0.744794
# Running loss: 0.926481
# Running loss: 1.023941
# Running loss: 0.695577
# Running loss: 1.280967
# Running loss: 1.021855
# Running loss: 1.902349
# Running loss: 0.965607
# Running loss: 0.638219
# Running loss: 0.876181
# Running loss: 1.050622
# Running loss: 0.675223
# Running loss: 0.915046
# Running loss: 0.644218
# Running loss: 0.360950
# Running loss: 0.994747
# Running loss: 1.797414
# Running loss: 0.821369
# Running loss: 0.876528
# Running loss: 0.547398
# Running loss: 0.944540
# Running loss: 1.097955
# Running loss: 0.673743
# Running loss: 0.312377
# Running loss: 1.124630
# Running loss: 0.678175
# Running loss: 0.870766
# Running loss: 1.149754
# Running loss: 1.314597
# Running loss: 1.243355
# Running loss: 1.681558
# Running loss: 0.850348
# Running loss: 0.828779
# Running loss: 0.278888
# Running loss: 1.057330
# Running loss: 0.715669
# Running loss: 1.001837
# Running loss: 1.224269
# Running loss: 0.497733
# Running loss: 0.456361
# Running loss: 1.478406
# Running loss: 1.327636
# Running loss: 2.547591
# Running loss: 1.426626
# Running loss: 1.447251
# Running loss: 0.816019
# Running loss: 1.420979
# Running loss: 0.656788
# Running loss: 1.323541
# Running loss: 0.301863
# Running loss: 1.107932
# Running loss: 1.722134
# Running loss: 0.904289
# Running loss: 0.917182
# Running loss: 0.821312
# Running loss: 0.665875
# Running loss: 0.650534
# Running loss: 1.196999
# Running loss: 0.818517
# Running loss: 0.948496
# Running loss: 1.132177
# Running loss: 0.766828
# Running loss: 1.117258
# Running loss: 2.098889
# Running loss: 0.441301
# Running loss: 1.086195
# Running loss: 0.957311
# Running loss: 0.793699
# Running loss: 1.212320
# Running loss: 0.209183
# Running loss: 0.543329
# Running loss: 1.036075
# Running loss: 0.833055
# Running loss: 0.418116
# Running loss: 1.568657
# Running loss: 1.067498
# Running loss: 1.284798
# Running loss: 0.504601
# Running loss: 1.611857
# Running loss: 0.540430
# Running loss: 1.072503
# Running loss: 0.802799
# Running loss: 0.412477
# Running loss: 0.698265
# Running loss: 0.565921
# Running loss: 0.453610
# Running loss: 0.944071
# Running loss: 0.464662
# Running loss: 0.862271
# Running loss: 0.484847
# Running loss: 0.541369
# Running loss: 0.398703
# Running loss: 1.355852
# Running loss: 0.212625
# Running loss: 1.148048
# Running loss: 0.992024
# Running loss: 1.248009
# Running loss: 0.932364
# Running loss: 1.396904
# Running loss: 1.119726
# Running loss: 0.963050
# Running loss: 1.079636
# Running loss: 0.950529
# Running loss: 1.603947
# Running loss: 0.867402
# Running loss: 0.786086
# Running loss: 1.422566
# Running loss: 0.514557
# Running loss: 0.404380
# Running loss: 0.593769
# Running loss: 0.699111
# Running loss: 0.463044
# Running loss: 0.549788
# Running loss: 0.397864
# Running loss: 0.939628
# Running loss: 0.894712
# Running loss: 0.508198
# Running loss: 0.882830
# Running loss: 1.202003
# Running loss: 0.884621
# Running loss: 1.377754
# Running loss: 0.807178
# Running loss: 1.705535
# Running loss: 1.191057
# Running loss: 0.912321
# Running loss: 1.099370
# Running loss: 0.954620
# Running loss: 1.454332
# Running loss: 0.719894
# Running loss: 1.214949
# Running loss: 1.015486
# Running loss: 1.134085
# Running loss: 0.721864
# Running loss: 0.839548
# Running loss: 1.006519
# Running loss: 0.872106
# Running loss: 1.133922
# Running loss: 0.967727
# Running loss: 0.966980
# Running loss: 1.260609
# Running loss: 0.562717
# Running loss: 0.854112
# Running loss: 0.439081
# Running loss: 2.029741
# Running loss: 0.660741
# Running loss: 1.290343
# Running loss: 0.560291
# Running loss: 1.038281
# Running loss: 1.436142
# Running loss: 0.958239
# Running loss: 1.210197
# Running loss: 0.825119
# Running loss: 0.785757
# Running loss: 1.020713
# Running loss: 0.525702
# Running loss: 0.561084
# Running loss: 1.266089
# Running loss: 0.680619
# Running loss: 1.146119
# Running loss: 0.657339
# Running loss: 0.334000
# Running loss: 0.638148
# Running loss: 0.908095
# Running loss: 0.588871
# Running loss: 1.171966
# Running loss: 1.652249
# Running loss: 1.244618
# Running loss: 1.176877
# Running loss: 0.387580
# Running loss: 0.465935
# Running loss: 1.332279
# Running loss: 0.149199
# Running loss: 0.983185
# Running loss: 0.578087
# Running loss: 1.592248
# Running loss: 0.648965
# Running loss: 0.772406
# Running loss: 0.794159
# Running loss: 1.372968
# Running loss: 0.807377
# Running loss: 0.926169
# Running loss: 0.955919
# Running loss: 0.327702
# Running loss: 0.775367
# Running loss: 0.934991
# Running loss: 0.664664
# Running loss: 0.350217
# Running loss: 1.681195
# Running loss: 0.447843
# Running loss: 0.640108
# Running loss: 0.897377
# Running loss: 1.170130
# Running loss: 1.077307
# Running loss: 0.761677
# Running loss: 0.881459
# Running loss: 0.548062
# Running loss: 0.438113
# Running loss: 0.498630
# Running loss: 1.190006
# Running loss: 1.668490
# Running loss: 0.330475
# Running loss: 0.807815
# Running loss: 0.680030
# Running loss: 1.922975
# Running loss: 1.811708
# Running loss: 0.486413
# Running loss: 1.225286
# Running loss: 0.630236
# Running loss: 0.756907
# Running loss: 0.383431
# Running loss: 1.339338
# Running loss: 1.100168
# Running loss: 1.253964
# Running loss: 1.547189
# Running loss: 0.297097
# Running loss: 0.871083
# Running loss: 1.519820
# Running loss: 0.651398
# Running loss: 0.777331
# Running loss: 0.723528
# Running loss: 1.195193
# Running loss: 1.667876
# Running loss: 1.644465
# Running loss: 0.712094
# Running loss: 0.989048
# Running loss: 0.722646
# Running loss: 0.446618
# Running loss: 0.938086
# Running loss: 0.385974
# Running loss: 0.601958
# Running loss: 0.947682
# Running loss: 0.698138
# Running loss: 0.581898
# Running loss: 0.205265
# Running loss: 1.402865
# Running loss: 0.781172
# Running loss: 1.361145
# Running loss: 0.845304
# Running loss: 0.446311
# Running loss: 1.001665
# Running loss: 1.035128
# Running loss: 1.246948
# Running loss: 1.190591
# Running loss: 1.144101
# Running loss: 1.160813
# Running loss: 0.856303
# Running loss: 0.645022
# Running loss: 0.820191
# Running loss: 1.073297
# Running loss: 1.120900
# Running loss: 0.810687
# Running loss: 1.076880
# Running loss: 1.036706
# Running loss: 0.671045
# Running loss: 0.413581
# Running loss: 0.465428
# Running loss: 1.521392
# Running loss: 0.857242
# Running loss: 1.427409
# Running loss: 1.340184
# Running loss: 1.044282
# Running loss: 0.527168
# Running loss: 0.272505
# Running loss: 1.250699
# Running loss: 1.445583
# Running loss: 1.422971
# Running loss: 0.670236
# Running loss: 0.852839
# Running loss: 0.754900
# Running loss: 0.652941
# Running loss: 0.539565
# Running loss: 0.711274
# Running loss: 1.260683
# Running loss: 0.698445
# Running loss: 0.814790
# Running loss: 0.893825
# Running loss: 0.631791
# Running loss: 0.897690
# Running loss: 1.124169
# Running loss: 1.597617
# Running loss: 0.698198
# Running loss: 0.558397
# Running loss: 0.613389
# Running loss: 0.607077
# Running loss: 1.051322
# Running loss: 0.474969
# Running loss: 0.813060
# Running loss: 0.705225
# Running loss: 0.628672
# Running loss: 1.787127
# Running loss: 0.999687
# Running loss: 1.177352
# Running loss: 0.996861
# Running loss: 1.189012
# Running loss: 0.526002
# Running loss: 1.074527
# Running loss: 0.699459
# Running loss: 0.761396
# Running loss: 0.530751
# Running loss: 0.642250
# Running loss: 1.458467
# Running loss: 0.682741
# Running loss: 1.593075
# Running loss: 0.690059
# Running loss: 1.357059
# Running loss: 0.763851
# Running loss: 1.067211
# Running loss: 0.418944
# Running loss: 1.951957
# Running loss: 2.388091
# Running loss: 0.970414
# Running loss: 0.571337
# Running loss: 1.030256
# Running loss: 0.533503
# Running loss: 0.829216
# Running loss: 1.049915
# Running loss: 0.568780
# Running loss: 0.461741
# Running loss: 0.987240
# Running loss: 0.845372
# Running loss: 1.309088
# Running loss: 1.145641
# Running loss: 1.018802
# Running loss: 0.645282
# Running loss: 0.968184
# Running loss: 0.927577
# Running loss: 0.765775
# Running loss: 0.640176
# Running loss: 1.137485
# Running loss: 0.888233
# Running loss: 1.406493
# Running loss: 1.195240
# Running loss: 1.388651
# Running loss: 0.993267
# Running loss: 0.586550
# Running loss: 0.880249
# Running loss: 0.892835
# Running loss: 0.931045
# Running loss: 0.513601
# Running loss: 0.859369
# Running loss: 0.639698
# Running loss: 0.610700
# Running loss: 0.878732
# Running loss: 1.109093
# Running loss: 0.708710
# Running loss: 0.860439
# Running loss: 0.290484
# Running loss: 1.355389
# Running loss: 0.801712
# Running loss: 0.876544
# Running loss: 1.101798
# Running loss: 1.452166
# Running loss: 0.762158
# Running loss: 1.139554
# Running loss: 0.823194
# Running loss: 0.608668
# Running loss: 0.647943
# Running loss: 1.128784
# Running loss: 1.400633
# Running loss: 0.887339
# Running loss: 0.982479
# Running loss: 0.947692
# Running loss: 0.543517
# Running loss: 1.243156
# Running loss: 1.068563
# Running loss: 1.036444
# Running loss: 0.812672
# Running loss: 1.621296
# Running loss: 0.352911
# Running loss: 0.810547
# Running loss: 2.050765
# Running loss: 1.105703
# Running loss: 0.883008
# Running loss: 0.859592
# Running loss: 0.781192
# Running loss: 1.424687
# Running loss: 0.496291
# Running loss: 0.831147
# Running loss: 0.787299
# Running loss: 0.445649
# Running loss: 0.361948
# Running loss: 0.458800
# Running loss: 0.614834
# Running loss: 0.194447
# Running loss: 1.534009
# Running loss: 0.526034
# Running loss: 0.292450
# Running loss: 1.222984
# Running loss: 0.444712
# Running loss: 1.008233
# Running loss: 0.563943
# Running loss: 0.441559
# Running loss: 1.553834
# Running loss: 0.939035
# Running loss: 0.752131
# Running loss: 1.312502
# Running loss: 0.675713
# Running loss: 0.894844
# Running loss: 0.965148
# Running loss: 0.293663
# Running loss: 0.815109
# Running loss: 1.155682
# Running loss: 0.523990
# Running loss: 1.448981
# Running loss: 2.023609
# Running loss: 0.584587
# Running loss: 1.001163
# Running loss: 0.817590
# Running loss: 1.421470
# Running loss: 0.478894
# Running loss: 1.307033
# Running loss: 1.365240
# Running loss: 1.071384
# Running loss: 0.536214
# Running loss: 0.390064
# Running loss: 0.723972
# Running loss: 0.959991
# Running loss: 1.102592
# Running loss: 0.543110
# Running loss: 1.053291
# Running loss: 0.777839
# Running loss: 0.714154
# Running loss: 0.788084
# Running loss: 0.641606
# Running loss: 0.890191
# Running loss: 0.548955
# Running loss: 1.265901
# Running loss: 0.348131
# Running loss: 0.730158
# Running loss: 0.628318
# Running loss: 1.078750
# ...
# Running loss: 0.383473
# Running loss: 0.590930
# Running loss: 0.688456
# Running loss: 0.758071
# Running loss: 0.527619
# Running loss: 0.400109
# Running loss: 0.559646
# Running loss: 0.649320
# Running loss: 1.009713
# Running loss: 0.903020
# Running loss: 0.902416
# Running loss: 0.584494
# Running loss: 0.753942
# Running loss: 1.284618
# Running loss: 0.200108
# Running loss: 0.754798
# Running loss: 0.695359
# Running loss: 0.792264
# Running loss: 0.353303
# Running loss: 1.433420
# Running loss: 0.863606
# Running loss: 0.184445
# Running loss: 0.548814
# Running loss: 0.364442
# Running loss: 0.377102
# Running loss: 0.256741
# Running loss: 1.042746
# Running loss: 0.389319
# Running loss: 0.697702
# Running loss: 0.822848
# Running loss: 0.955815
# Running loss: 1.019666
# Running loss: 0.262423
# Running loss: 0.426328
# Running loss: 0.690885
# Running loss: 0.541343
# Running loss: 0.361507
# Running loss: 0.821294
# Running loss: 0.412443
# Running loss: 0.519054
# Running loss: 0.642573
# Running loss: 0.591902
# Running loss: 0.734671
# Running loss: 0.358325
# Running loss: 0.494864
# Running loss: 0.734421
# Running loss: 0.620610
# Running loss: 0.691853
# Running loss: 0.703981
# Running loss: 0.535837
# Running loss: 0.991783
# Running loss: 1.199545
# Running loss: 0.453056
# Running loss: 0.463041
# Running loss: 0.496188
# Running loss: 0.907185
# Running loss: 0.435523
# Running loss: 0.516535
# Running loss: 0.875778
# Running loss: 0.415448
# Running loss: 0.595944
# Running loss: 1.350393
# Running loss: 1.087328
# Running loss: 0.848812
# Running loss: 0.231358
# Running loss: 0.605989
# Running loss: 0.548184
# Running loss: 0.808267
# Running loss: 0.959802
# Running loss: 0.706349
# Running loss: 0.541804
# Running loss: 0.444879
# Running loss: 0.812224
# Running loss: 0.466907
# Running loss: 0.571084
# Running loss: 0.611186
# Running loss: 0.814389
# Running loss: 0.593656
# Running loss: 0.676659
# Running loss: 0.576716
# Running loss: 0.391395
# Running loss: 1.811298
# Running loss: 0.995353
# Running loss: 0.518668
# Running loss: 0.746027
# Running loss: 1.011113
# Running loss: 1.234903
# Running loss: 0.578442
# Running loss: 0.851429
# Running loss: 0.773558
# Running loss: 0.640479
# Running loss: 0.526682
# Running loss: 0.415156
# Running loss: 0.418930
# Running loss: 0.213747
# Running loss: 0.653302
# Running loss: 0.724643
# Running loss: 0.802781
# Running loss: 1.141744
# Running loss: 0.397498
# Running loss: 0.636399
# Running loss: 1.137291
# Running loss: 0.884083
# Running loss: 1.344579
# Running loss: 0.523599
# Running loss: 0.436561
# Running loss: 0.004809
# Running loss: 1.338730
# Running loss: 0.833362
# Running loss: 0.745657
# Running loss: 0.464240
# Running loss: 0.302434
# Running loss: 0.723001
# Running loss: 0.439956
# Running loss: 0.514156
# Running loss: 0.249298
# Running loss: 0.765495
# Running loss: 0.281684
# Running loss: 0.684359
# Running loss: 1.095260
# Running loss: 1.183179
# Running loss: 0.929653
# Running loss: 0.731441
# Running loss: 0.557348
# Running loss: 0.862592
# Running loss: 0.489454
# Running loss: 0.955010
# Running loss: 0.940980
# Running loss: 0.671342
# Running loss: 0.544782
# Running loss: 0.831272
# Running loss: 0.335667
# Running loss: 0.887549
# Running loss: 0.754374
# Running loss: 0.917693
# Running loss: 0.710010
# Running loss: 0.448600
# Running loss: 0.737436
# Running loss: 0.608225
# Running loss: 0.590185
# Running loss: 0.651882
# Running loss: 0.683968
# Running loss: 1.177409
# Running loss: 1.207989
# Running loss: 0.861277
# Running loss: 0.890697
# Running loss: 0.403221
# Running loss: 0.575928
# Running loss: 1.303263
# Running loss: 0.846741
# Running loss: 0.572392
# Running loss: 0.680883
# Running loss: 0.442164
# Running loss: 0.412507
# Running loss: 0.874916
# Running loss: 0.561248
# Running loss: 0.846688
# Running loss: 0.453372
# Running loss: 0.467339
# Running loss: 0.358905
# Running loss: 0.676459
# Running loss: 0.916130
# Running loss: 0.542644
# Running loss: 0.297944
# Running loss: 0.566213
# Running loss: 0.881131
# Running loss: 1.068003
# Running loss: 0.593800
# Running loss: 0.558092
# Running loss: 0.719338
# Running loss: 0.832525
# Running loss: 0.281590
# Running loss: 1.106168
# Running loss: 0.767460
# Running loss: 0.365113
# Running loss: 0.673437
# Running loss: 0.511404
# Running loss: 0.528538
# Running loss: 0.348546
# Running loss: 0.443989
# Running loss: 0.286062
# Running loss: 1.104462
# Running loss: 0.480847
# Running loss: 0.711458
# Running loss: 0.257417
# Running loss: 0.573069
# Running loss: 0.473272
# Running loss: 0.279875
# Running loss: 1.052850
# Running loss: 0.705075
# Running loss: 0.414163
# Running loss: 1.055510
# Running loss: 0.583061
# Running loss: 0.452139
# Running loss: 0.371755
# Running loss: 0.738105
# Running loss: 0.712184
# Running loss: 0.726282
# Running loss: 0.722894
# Running loss: 0.337182
# Running loss: 0.706406
# Running loss: 0.788693
# Running loss: 0.795116
# Running loss: 0.322766
# Running loss: 0.538093
# Running loss: 0.938405
# Running loss: 0.954307
# Running loss: 0.297932
# Running loss: 0.306428
# Running loss: 0.701786
# Running loss: 0.576948
# Running loss: 0.554977
# Running loss: 0.564941
# Running loss: 1.199256
# Running loss: 1.021169
# Running loss: 0.860894
# Running loss: 0.243376
# Running loss: 0.839190
# Running loss: 1.002637
# Running loss: 0.959291
# Running loss: 0.758363
# Running loss: 0.582633
# Running loss: 0.502551
# Running loss: 0.211314
# Running loss: 0.926758
# Running loss: 0.292946
# Running loss: 0.806127
# Running loss: 0.450467
# Running loss: 1.377292
# Running loss: 0.772164
# Running loss: 0.346515
# Running loss: 0.981555
# Running loss: 1.656802
# Running loss: 0.786524
# Running loss: 0.526731
# Running loss: 0.161365
# Running loss: 0.497946
# Running loss: 0.725686
# Running loss: 0.259282
# Running loss: 0.839389
# Running loss: 0.412058
# Running loss: 1.147557
# Running loss: 0.060490
# Running loss: 0.828567
# Running loss: 0.674591
# Running loss: 1.080653
# Running loss: 0.858020
# Running loss: 0.271981
# Running loss: 0.836627
# Running loss: 0.356326
# Running loss: 0.648882
# Running loss: 0.716493
# Running loss: 0.344954
# Running loss: 0.564823
# Running loss: 1.019083
# Running loss: 0.661392
# Running loss: 0.833988
# Running loss: 0.988283
# Running loss: 0.484939
# Running loss: 0.859503
# Running loss: 0.504877
# Running loss: 0.682725
# Running loss: 0.081293
# Running loss: 0.511348
# Running loss: 0.820292
# Running loss: 1.257092
# Running loss: 0.559974
# Running loss: 0.600736
# Running loss: 0.596508
# Running loss: 0.589940
# Running loss: 1.311171
# Running loss: 0.824270
# Running loss: 0.721469
# Running loss: 0.364843
# Running loss: 1.042246
# Running loss: 1.313612
# Running loss: 0.794567
# Running loss: 1.198170
# Running loss: 0.815605
# Running loss: 0.503295
# Running loss: 0.412698
# Running loss: 0.996879
# Running loss: 0.765778
# Running loss: 0.672940
# Running loss: 0.607460
# Running loss: 0.632089
# Running loss: 0.661622
# Running loss: 1.229639
# Running loss: 0.196830
# Running loss: 0.833929
# Running loss: 0.712543
# Running loss: 0.731152
# Running loss: 0.350270
# Running loss: 1.809789
# Running loss: 0.723539
# Running loss: 1.830347
# Running loss: 0.694335
# Running loss: 0.483680
# Running loss: 0.337528
# Running loss: 0.673725
# Running loss: 0.385782
# Running loss: 1.067465
# Running loss: 0.451182
# Running loss: 0.387649
# Running loss: 0.642240
# Running loss: 0.688346
# Running loss: 0.515310
# Running loss: 0.786302
# Running loss: 0.770074
# Running loss: 0.503222
# Running loss: 0.930361
# Running loss: 0.424525
# Running loss: 0.438397
# Running loss: 0.262462
# Running loss: 0.148817
# Running loss: 0.689655
# Running loss: 0.767408
# Running loss: 0.757052
# Running loss: 0.205468
# Running loss: 0.736513
# Running loss: 0.561763
# Running loss: 0.909430
# Running loss: 1.102070
# Running loss: 0.595033
# Running loss: 0.423533
# Running loss: 1.378115
# Running loss: 0.577044
# Running loss: 1.087997
# Running loss: 0.567035
# Running loss: 0.219196
# Running loss: 0.356942
# Running loss: 0.274475
# Running loss: 0.852623
# Running loss: 1.066055
# Running loss: 1.032939
# Running loss: 0.330123
# Running loss: 0.542205
# Running loss: 0.513037
# Running loss: 1.471968
# Running loss: 0.601037
# Running loss: 0.714667
# Running loss: 0.342713
# Running loss: 1.466294
# Running loss: 0.593456
# Running loss: 0.662332
# Running loss: 0.322964
# Running loss: 0.738607
# Running loss: 0.745528
# Running loss: 0.248986
# Running loss: 1.143595
# Running loss: 1.004220
# Running loss: 0.970982
# Running loss: 0.520009
# Running loss: 0.370334
# Running loss: 0.462108
# Running loss: 0.834129
# Running loss: 0.825523
# Running loss: 0.842121
# Running loss: 1.398228
# Running loss: 0.386904
# Running loss: 0.207311
# Running loss: 0.789777
# Running loss: 0.373555
# Running loss: 0.536145
# Running loss: 0.647699
# Running loss: 0.775091
# Running loss: 0.766492
# Running loss: 0.561905
# Running loss: 1.468112
# Running loss: 0.462214
# Running loss: 0.928129
# Running loss: 0.820843
# Running loss: 0.405778
# Running loss: 0.571518
# Running loss: 1.055054
# Running loss: 0.428172
# Running loss: 0.248866
# Running loss: 0.707842
# Running loss: 0.304893
# Running loss: 0.711536
# Running loss: 0.528852
# Running loss: 1.056213
# Running loss: 1.175475
# Running loss: 0.466085
# Running loss: 0.392108
# Running loss: 1.266038
# Running loss: 0.850255
# Running loss: 0.432371
# Running loss: 1.281482
# Running loss: 0.996577
# Running loss: 0.890109
# Running loss: 0.895678
# Running loss: 0.702221
# Running loss: 0.976196
# Running loss: 0.478504
# Running loss: 0.678433
# Running loss: 0.489595
# Running loss: 0.894774
# Running loss: 0.732600
# Running loss: 0.389347
# Running loss: 0.551330
# Running loss: 0.592512
# Running loss: 0.657124
# Running loss: 0.773490
# Running loss: 0.702330
# Running loss: 0.604354
# Running loss: 0.474865
# Running loss: 0.517078
# Running loss: 0.573564
# Running loss: 0.596809
# Running loss: 0.517424
# Running loss: 0.430084
# Running loss: 0.970598
# Running loss: 1.096841
# Running loss: 0.939669
# Running loss: 1.062509
# Running loss: 0.823077
# Running loss: 0.740344
# Running loss: 0.474735
# Running loss: 0.872565
# Running loss: 0.434359
# Running loss: 0.657433
# Running loss: 0.596848
# Running loss: 0.592909
# Running loss: 0.446449
# Running loss: 1.181133
# Running loss: 0.427321
# Running loss: 0.651699
# Running loss: 1.092698
# Running loss: 0.978524
# Running loss: 0.701970
# Running loss: 0.442956
# Running loss: 0.932113
# Running loss: 0.551342
# Running loss: 0.214520
# Running loss: 0.521904
# Running loss: 1.429599
# Running loss: 0.743068
# Running loss: 0.180816
# Running loss: 1.352692
# Running loss: 1.612171
# Running loss: 0.863459
# Running loss: 1.196278
# Running loss: 0.069972
# Running loss: 0.950055
# Running loss: 0.641204
# Running loss: 0.493669
# Running loss: 0.553172
# Running loss: 0.476329
# Running loss: 0.937743
# Running loss: 0.782709
# Running loss: 0.781283
# Running loss: 0.736486
# Running loss: 1.228000
# Running loss: 0.934097
# Running loss: 0.133897
# Running loss: 0.379036
# Running loss: 0.126468
# Running loss: 0.494293
# Running loss: 0.753423
# Running loss: 0.520927
# Running loss: 0.241400
# Running loss: 1.014179
# Running loss: 0.622716
# Running loss: 0.470353
# Running loss: 0.382632
# Running loss: 0.515505
# Running loss: 0.418430
# Running loss: 0.538536
# Running loss: 0.115665
# Running loss: 0.402847
# Running loss: 0.174155
# Running loss: 1.454273
# Running loss: 0.935566
# Running loss: 0.788676
# Running loss: 0.917802
# Running loss: 0.267426
# Running loss: 1.263752
# Running loss: 0.608074
# Running loss: 0.575918
# Running loss: 0.732818
# Running loss: 0.575355
# Running loss: 1.245541
# Running loss: 0.657320
# Running loss: 0.994795
# Running loss: 1.075847
# Running loss: 0.437689
# Running loss: 0.984527
# Running loss: 0.477287
# Running loss: 0.652447
# Running loss: 1.515925
# Running loss: 1.105264
# Running loss: 0.592854
# Running loss: 0.288293
# Running loss: 0.342460
# Running loss: 0.550438
# Running loss: 0.824927
# Running loss: 0.404895
# Running loss: 0.961289
# Running loss: 0.209625
# Running loss: 0.813437
# Running loss: 0.962272
# Running loss: 1.205836
# Running loss: 0.629847
# Running loss: 0.686083
# Running loss: 0.418615
# Running loss: 0.286448
# Running loss: 0.762865
# Running loss: 0.484645
# Running loss: 0.411445
# Running loss: 1.371715
# Running loss: 0.912124
# Running loss: 1.124381
# Running loss: 0.653795
# Running loss: 1.013381
# Running loss: 0.837464
# Running loss: 0.740658
# Running loss: 1.182398
# Running loss: 0.891610
# Running loss: 0.841951
# Running loss: 0.662060
# Running loss: 0.889994
# Running loss: 0.506031
# Running loss: 0.228940
# Running loss: 0.785277
# Running loss: 0.523086
# Running loss: 0.872440
# Running loss: 0.800329
# Running loss: 0.648397
# Running loss: 0.494803
# Running loss: 1.147787
# Running loss: 0.593787
# Running loss: 0.144898
# Running loss: 0.938701
# Running loss: 0.402709
# Running loss: 0.645056
# Running loss: 0.577287
# Running loss: 0.446757
# Running loss: 0.665731
# Running loss: 0.831777
# Running loss: 0.591397
# Running loss: 0.729976
# Running loss: 0.736310
# Running loss: 0.510372
# Running loss: 0.848130
# Running loss: 0.197192
# Running loss: 0.266877
# Running loss: 0.787455
# Running loss: 0.791615
# Running loss: 0.608011
# Running loss: 0.587241
# Running loss: 0.620113
# Running loss: 0.133105
# Running loss: 0.194835
# Running loss: 1.049128
# Running loss: 0.810437
# Running loss: 0.318982
# Running loss: 0.200832
# Running loss: 1.025982
# Running loss: 0.900549
# Running loss: 0.480999
# Running loss: 0.702826
# Running loss: 0.462248
# Running loss: 0.435276
# Running loss: 1.079987
# Running loss: 1.297177
# Running loss: 1.341308
# Running loss: 0.626691
# Running loss: 0.732951
# Running loss: 1.283676
# Running loss: 0.391705
# Running loss: 0.989830
# Running loss: 0.356782
# Running loss: 0.353020
# Running loss: 0.942223
# Running loss: 0.575464
# Running loss: 0.676660
# Running loss: 0.758243
# Running loss: 0.385001
# Running loss: 0.863601
# Running loss: 0.200635
# Running loss: 0.239660
# Running loss: 0.544627
# Running loss: 0.493402
# Running loss: 0.101767
# Running loss: 0.699897
# Running loss: 0.185578
# Running loss: 0.481117
# Running loss: 0.482030
# Running loss: 0.325225
# Running loss: 0.842903
# Running loss: 0.576094
# Running loss: 0.552563
# Running loss: 0.694545
# Running loss: 1.327896
# Running loss: 0.718282
# Running loss: 0.581953
# Running loss: 1.600771
# Running loss: 1.507905
# Running loss: 1.439001
# Running loss: 0.611448
# Running loss: 0.351541
# Running loss: 0.460514
# Running loss: 0.319613
# Running loss: 1.130050
# Running loss: 0.601941
# Running loss: 0.258546
# Running loss: 0.812056
# Running loss: 0.902213
# Running loss: 0.724038
# Running loss: 0.852612
# Running loss: 0.545373
# Running loss: 0.131260
# Running loss: 0.221608
# Running loss: 0.538720
# Running loss: 0.631316
# Running loss: 0.481089
# Running loss: 0.962011
# Running loss: 0.813225
# Running loss: 0.395848
# Running loss: 0.423463
# Running loss: 0.813644
# Running loss: 1.002993
# Running loss: 0.238727
# Running loss: 1.007280
# Running loss: 0.635447
# Running loss: 0.777139
# Running loss: 1.181640
# Running loss: 0.545620
# Running loss: 0.762894
# Running loss: 1.088294
# Running loss: 1.240262
# Running loss: 0.386606
# Running loss: 0.732586
# Running loss: 0.803802
# Running loss: 0.942781
# Running loss: 1.014658
# Running loss: 1.514882
# Running loss: 0.796701
# Running loss: 0.993074
# Running loss: 0.653063
# Running loss: 0.622713
# Running loss: 0.424649
# Running loss: 0.807352
# Running loss: 0.742163
# Running loss: 0.954969
# Running loss: 0.662824
# Running loss: 0.656473
# Running loss: 0.360381
# Running loss: 0.252361
# Running loss: 1.185624
# Running loss: 0.594197
# Running loss: 1.184835
# Running loss: 0.425313
# Running loss: 0.236450
# Running loss: 0.338006
# Running loss: 0.095045
# Running loss: 1.225901
# Running loss: 0.574983
# Running loss: 0.836282
# Running loss: 0.491166
# Running loss: 0.288190
# Running loss: 0.710583
# Running loss: 0.619882
# Running loss: 0.662139
# Running loss: 0.825488
# Running loss: 0.713255
# Running loss: 1.012159
# Running loss: 0.389164
# Running loss: 0.540723
# Running loss: 0.636116
# Running loss: 0.699419
# Running loss: 0.698173
# Running loss: 0.352339
# Running loss: 0.373513
# Running loss: 1.163918
# Running loss: 0.517407
# Running loss: 0.425390
# Running loss: 0.826446
# Running loss: 0.514866
# Running loss: 0.348147
# Running loss: 0.766980
# Running loss: 0.261272
# Running loss: 0.388463
# Running loss: 0.282371
# Running loss: 0.757685
# Running loss: 0.179064
# Running loss: 0.772045
# Running loss: 1.052909
# Running loss: 0.186330
# Current iteration: 100%|██████████| 3435/3435 [36:28<00:00,  1.57it/s]
# Epoch: 100%|██████████| 2/2 [1:12:53<00:00, 2186.68s/it]

# %%
pred = model.predict(test_json_format)
# Out:
# 100%|██████████| 3534/3534 [00:03<00:00, 1092.72it/s]
# 100%|██████████| 442/442 [01:19<00:00,  5.57it/s]

# %%
df = pd.DataFrame.from_dict(pred)

sample_submission["selected_text"] = df["answer"]

sample_submission.to_csv("C:/Users/aaron/OneDrive/Documents/AARON ECOLE/ESG FINANCE/MACHINE_LEARNING/TP/TP3/tweet-sentiment-extraction/Data/Ouput/submission.csv", index = False)

print("File submitted successfully.")
# Out:
# File submitted successfully.
